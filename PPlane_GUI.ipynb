# %%
# %matplotlib inline
import numpy as np
import jinja2
import json
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.path as mpath
import matplotlib.patches as mpatches

import mpld3
from mpld3 import plugins, utils

class PPlanePlugin(plugins.PluginBase):
    JAVASCRIPT = r"""
    // init custom PPLane plugin
    mpld3.register_plugin("drag", PPlanePlugin);
    PPlanePlugin.prototype = Object.create(mpld3.Plugin.prototype);
    PPlanePlugin.prototype.constructor = PPlanePlugin;
    PPlanePlugin.prototype.requiredProps = ["id", "idmpoint", "idlinesl", "idlinesr", 
                                            "idqlm", "idqmm", "idqrm", "idqone", "idqtwo", "idzz"];
    PPlanePlugin.prototype.defaultProps = {}
    function PPlanePlugin(fig, props){
        mpld3.Plugin.call(this, fig, props);
        mpld3.insert_css("#" + fig.figid + " path.dragging",
                         {"fill-opacity": "1.0 !important",
                          "stroke-opacity": "1.0 !important"});
    };

    // Call draw function, this function is being looped all the time
    PPlanePlugin.prototype.draw = function(){
        // Get elements into script variables
        var obj = mpld3.get_element(this.props.id);
        var midpoint = mpld3.get_element(this.props.idmpoint);
        var linesl = mpld3.get_element(this.props.idlinesl);
        var linesr = mpld3.get_element(this.props.idlinesr);
        var qlm = mpld3.get_element(this.props.idqlm);
        var qmm = mpld3.get_element(this.props.idqmm);
        var qrm = mpld3.get_element(this.props.idqrm);
        var qone = mpld3.get_element(this.props.idqone);
        var qtwo = mpld3.get_element(this.props.idqtwo);
        var zz = this.props.idzz;


        // Set initial conditions for javascript calculations
        var qleft = obj.offsets[0];
        var qright = obj.offsets[1];
        var qmid = midpoint.offsets[0];
        
        // Main d3 drag function
        var drag = d3.behavior.drag()
            .origin(function(d) { return {x:obj.ax.x(d[0]),
                                          y:obj.ax.y(d[1])}; })                              
            .on("dragstart", dragstarted)
            .on("drag", dragged)
            .on("dragend", dragended);
    
        // Set elements of ql and qr points and call main drag function
        obj.elements()
           .data(obj.offsets)
           .style("cursor", "default")
           .call(drag);      

        // Begin drag function
        function dragstarted(d) {
          d3.event.sourceEvent.stopPropagation();
          d3.select(this).classed("dragging", true);
        }
    
        // The drag function called while dragging is happening (meat of code here)
        function dragged(d,i) {
          // Convert mouse coordinates in drag event (d3.event) to python coordinates d
          d[0] = obj.ax.x.invert(d3.event.x);
          d[1] = obj.ax.y.invert(d3.event.y);             
          // Move ql and qr stored in obj (they have been selected in drag)
          d3.select(this)
            .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
          // If obj corresponds to ql, move all the other left elements 
          if (i==0){
              // Move lines and text marker
              linesl.elements().transition().duration(5)
                  .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
              qlm.elements().transition().duration(1)
                  .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
              // In script calculations of middle state
              qleft = [d[0], d[1]];
              var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
              qmid[0] = qleft[0] - alphal*zz;
              qmid[1] = qleft[1] + alphal;
              var xx = obj.ax.x(qmid[0]);
              var yy = obj.ax.y(qmid[1]); 
              // Update middle state point and marker position
              midpoint.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
              qmm.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")"); 
                
              // Update subplots of q1 and q2
              qone.data[0][1] = qleft[0];
              qone.data[1][1] = qleft[0];
              qone.data[2][1] = qmid[0];
              qone.data[3][1] = qmid[0];
              qtwo.data[0][2] = qleft[1];
              qtwo.data[1][2] = qleft[1];
              qtwo.data[2][2] = qmid[1];
              qtwo.data[3][2] = qmid[1];
              qone.elements().transition()
                .attr("d", qone.datafunc(qone.data));
              qtwo.elements().transition()
                .attr("d", qtwo.datafunc(qtwo.data));
                }
          // if element corresponds to qr
          else {
              // Move lines and text marker
              linesr.elements().transition().duration(5)
                  .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
              qrm.elements().transition().duration(1)
                  .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
              // In script calculations of middle state    
              qright = [d[0], d[1]];
              var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
              qmid[0] = qleft[0] - alphal*zz;
              qmid[1] = qleft[1] + alphal;
              var xx = obj.ax.x(qmid[0]);
              var yy = obj.ax.y(qmid[1]);
              // Update middle state point and marker position
              midpoint.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
              qmm.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
               // Update subplots of q1 and q2
              qone.data[2][1] = qmid[0];
              qone.data[3][1] = qmid[0];
              qone.data[4][1] = qright[0];
              qone.data[5][1] = qright[0];
              qtwo.data[2][2] = qmid[1];
              qtwo.data[3][2] = qmid[1];
              qtwo.data[4][2] = qright[1];
              qtwo.data[5][2] = qright[1];
              qone.elements().transition()
                .attr("d", qone.datafunc(qone.data));
              qtwo.elements().transition()
                .attr("d", qtwo.datafunc(qtwo.data));
                }
        }
        // End dragging
        function dragended(d) {
          d3.select(this).classed("dragging", false);
        }
    }
    mpld3.register_plugin("drag", PPlanePlugin); 
    """

    def __init__(self, points, midpoint, linesl, linesr, qlmarker, qmmarker, qrmarker, qone, qtwo,zz):
        if isinstance(points, mpl.lines.Line2D):
            suffix = "pts"
        else:
            suffix = None

        self.dict_ = {"type": "drag",
                      "id": utils.get_id(points, suffix),
                      "idmpoint": utils.get_id(midpoint,suffix),
                      "idlinesl": utils.get_id(linesl,suffix),
                      "idlinesr": utils.get_id(linesr,suffix),
                      "idqlm": utils.get_id(qlmarker,suffix),
                      "idqmm": utils.get_id(qmmarker,suffix),
                      "idqrm": utils.get_id(qrmarker,suffix),
                      "idqone": utils.get_id(qone),
                      "idqtwo": utils.get_id(qtwo),
                      "idzz": zz}


# Create figure
# Create a figure
fig, ax = plt.subplots(1,3, figsize=(13.5, 4.5))
fig.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=0.95,
                    hspace=0.3, wspace=0.15)

#Create subfigure ax1 for phaseplane
#ax[0] = fig.add_subplot(2,2,1)

# Calculate ql and qr randomly
qL = np.array([-2.0, 3.0])
qR = np.array([0.0, -2.0])
dq = np.array([qR[0]-qL[0], qR[1]-qL[1]])

# Plot eigenlines using paths as markers
zz = 2.0
rl = np.array([-zz, 1])
rr = np.array([zz,  1])
# Create path following eigenvalues r1 and r2
verts = [
    (-rl[0], -rl[1]), # left, bottom
    (rl[0], rl[1]), # left, top
    (-rr[0], -rr[1]), # left, bottom
    (rr[0], rr[1]), # left, top
    ]
codes = [mpath.Path.MOVETO,
         mpath.Path.LINETO,
         mpath.Path.LINETO,
         mpath.Path.LINETO
         ]
path = mpath.Path(verts, codes)

#Plot lines across ql and qr using paths as markers
linesl = ax[0].plot(qL[0],qL[1], 'k', marker=path, markersize=2550, fillstyle='none')
linesr = ax[0].plot(qR[0],qR[1], 'k', marker=path, markersize=2550, fillstyle='none')

# Plot ql and qr
points = ax[0].plot([qL[0],qR[0]], [qL[1], qR[1]], 'or', alpha=0.7, markersize=30, markeredgewidth=1)
data = ["q_l", "q_r"] 
qlmarker = ax[0].plot(qL[0], qL[1], 'ok', marker=(r"$ q_l $"), markersize=15)
qrmarker = ax[0].plot(qR[0], qR[1], 'ok', marker=(r"$ q_r $"), markersize=15)

#Plot midpoint
alL = (-dq[0] + dq[1]*zz)/(2*zz)
qm = qL + alL*rl 
midpoint = ax[0].plot(qm[0],qm[1],'ob', alpha=0.5, markersize=20, markeredgewidth=1)
qmmarker = ax[0].plot(qm[0],qm[1], 'k',marker=(r"$ q_m $"),markersize=12)

# Set axis 1 properties
ax[0].set_title("Phase Plane", fontsize=18)
ax[0].axis([-5,5,-5,5])
ax[0].set_aspect('equal')
ax[0].grid(alpha=0.1,color='k', linestyle='--')

# Remove defult mpld3 plugins
plugins.clear(fig)

#Create subfigure ax2 for solution plane
#ax[1] = fig.add_subplot(2,2,3)
# Create solutionl line with six points
xsol = np.array([-5.0,-2.0,-2.0,2.0,2.0,5.0])
qsol1 = 1*xsol
qsol1[0:2] = qL[0]
qsol1[2:4] = qm[0]
qsol1[4:6] = qR[0]

# Set axis 2 properties
ax[1].set_title("q1 at time = 3", fontsize=18)
ax[1].axis([-5,5,-5,5])
ax[1].grid(alpha=0.1,color='k', linestyle='--')
ax[1].set_aspect('equal')

# Plot solution
qone = ax[1].plot(xsol, qsol1, linewidth = 4, alpha = 0.5)

#Create subfigure ax2 for solution plane
#ax[2] = fig.add_subplot(2,2,2)
# Create solutionl line with six points
xsol2 = np.array([-5.0,-2.0,-2.0,2.0,2.0,5.0])
qsol2 = 1*xsol2
qsol2[0:2] = qL[1]
qsol2[2:4] = qm[1]
qsol2[4:6] = qR[1]

# Set axis 2 properties
ax[2].set_title("q2 at time = 3", fontsize=18)
ax[2].axis([-5,5,-5,5])
ax[2].grid(alpha=0.1,color='k', linestyle='--')
ax[2].set_aspect('equal')

# Plot solution
qtwo = ax[2].plot(xsol2, qsol2, linewidth = 4, alpha = 0.5)

# Call mpld3 custom PPLane plugin to interact with plot
plugins.connect(fig, PPlanePlugin(points[0],midpoint[0],linesl[0],linesr[0],qlmarker[0],
                                  qmmarker[0],qrmarker[0],qone[0],qtwo[0],zz))

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el6929774155684526804174"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     // init custom PPLane plugin
#     mpld3.register_plugin("drag", PPlanePlugin);
#     PPlanePlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     PPlanePlugin.prototype.constructor = PPlanePlugin;
#     PPlanePlugin.prototype.requiredProps = ["id", "idmpoint", "idlinesl", "idlinesr",
#                                             "idqlm", "idqmm", "idqrm", "idqone", "idqtwo", "idzz"];
#     PPlanePlugin.prototype.defaultProps = {}
#     function PPlanePlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#         mpld3.insert_css("#" + fig.figid + " path.dragging",
#                          {"fill-opacity": "1.0 !important",
#                           "stroke-opacity": "1.0 !important"});
#     };
#
#     // Call draw function, this function is being looped all the time
#     PPlanePlugin.prototype.draw = function(){
#         // Get elements into script variables
#         var obj = mpld3.get_element(this.props.id);
#         var midpoint = mpld3.get_element(this.props.idmpoint);
#         var linesl = mpld3.get_element(this.props.idlinesl);
#         var linesr = mpld3.get_element(this.props.idlinesr);
#         var qlm = mpld3.get_element(this.props.idqlm);
#         var qmm = mpld3.get_element(this.props.idqmm);
#         var qrm = mpld3.get_element(this.props.idqrm);
#         var qone = mpld3.get_element(this.props.idqone);
#         var qtwo = mpld3.get_element(this.props.idqtwo);
#         var zz = this.props.idzz;
#
#
#         // Set initial conditions for javascript calculations
#         var qleft = obj.offsets[0];
#         var qright = obj.offsets[1];
#         var qmid = midpoint.offsets[0];
#
#         // Main d3 drag function
#         var drag = d3.behavior.drag()
#             .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                           y:obj.ax.y(d[1])}; })
#             .on("dragstart", dragstarted)
#             .on("drag", dragged)
#             .on("dragend", dragended);
#
#         // Set elements of ql and qr points and call main drag function
#         obj.elements()
#            .data(obj.offsets)
#            .style("cursor", "default")
#            .call(drag);
#
#         // Begin drag function
#         function dragstarted(d) {
#           d3.event.sourceEvent.stopPropagation();
#           d3.select(this).classed("dragging", true);
#         }
#
#         // The drag function called while dragging is happening (meat of code here)
#         function dragged(d,i) {
#           // Convert mouse coordinates in drag event (d3.event) to python coordinates d
#           d[0] = obj.ax.x.invert(d3.event.x);
#           d[1] = obj.ax.y.invert(d3.event.y);
#           // Move ql and qr stored in obj (they have been selected in drag)
#           d3.select(this)
#             .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#           // If obj corresponds to ql, move all the other left elements
#           if (i==0){
#               // Move lines and text marker
#               linesl.elements().transition().duration(5)
#                   .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
#               qlm.elements().transition().duration(1)
#                   .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
#               // In script calculations of middle state
#               qleft = [d[0], d[1]];
#               var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
#               qmid[0] = qleft[0] - alphal*zz;
#               qmid[1] = qleft[1] + alphal;
#               var xx = obj.ax.x(qmid[0]);
#               var yy = obj.ax.y(qmid[1]);
#               // Update middle state point and marker position
#               midpoint.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#               qmm.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#
#               // Update subplots of q1 and q2
#               qone.data[0][1] = qleft[0];
#               qone.data[1][1] = qleft[0];
#               qone.data[2][1] = qmid[0];
#               qone.data[3][1] = qmid[0];
#               qtwo.data[0][2] = qleft[1];
#               qtwo.data[1][2] = qleft[1];
#               qtwo.data[2][2] = qmid[1];
#               qtwo.data[3][2] = qmid[1];
#               qone.elements().transition()
#                 .attr("d", qone.datafunc(qone.data));
#               qtwo.elements().transition()
#                 .attr("d", qtwo.datafunc(qtwo.data));
#                 }
#           // if element corresponds to qr
#           else {
#               // Move lines and text marker
#               linesr.elements().transition().duration(5)
#                   .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
#               qrm.elements().transition().duration(1)
#                   .attr("transform", "translate(" + [d3.event.x, d3.event.y] + ")");
#               // In script calculations of middle state
#               qright = [d[0], d[1]];
#               var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
#               qmid[0] = qleft[0] - alphal*zz;
#               qmid[1] = qleft[1] + alphal;
#               var xx = obj.ax.x(qmid[0]);
#               var yy = obj.ax.y(qmid[1]);
#               // Update middle state point and marker position
#               midpoint.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#               qmm.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#                // Update subplots of q1 and q2
#               qone.data[2][1] = qmid[0];
#               qone.data[3][1] = qmid[0];
#               qone.data[4][1] = qright[0];
#               qone.data[5][1] = qright[0];
#               qtwo.data[2][2] = qmid[1];
#               qtwo.data[3][2] = qmid[1];
#               qtwo.data[4][2] = qright[1];
#               qtwo.data[5][2] = qright[1];
#               qone.elements().transition()
#                 .attr("d", qone.datafunc(qone.data));
#               qtwo.elements().transition()
#                 .attr("d", qtwo.datafunc(qtwo.data));
#                 }
#         }
#         // End dragging
#         function dragended(d) {
#           d3.select(this).classed("dragging", false);
#         }
#     }
#     mpld3.register_plugin("drag", PPlanePlugin);
#
#        mpld3.draw_figure("fig_el6929774155684526804174", {"axes": [{"xlim": [-5.0, 5.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "Phase Plane", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 18.0, "position": [0.5, 1.0188614540466392], "rotation": -0.0, "id": "el692981776080"}], "zoomable": true, "images": [], "xdomain": [-5.0, 5.0], "ylim": [-5.0, 5.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 0.1, "dasharray": "6,6", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 0.1, "dasharray": "6,6", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#000000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el692976123344"}, {"color": "#000000", "yindex": 0, "coor

# %%
# %matplotlib inline
import numpy as np
import jinja2
import json
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.path as mpath
import matplotlib.patches as mpatches


import mpld3
from mpld3 import plugins, utils

class PPlanePlugin(plugins.PluginBase):
    JAVASCRIPT = r"""
    // init custom PPLane plugin
    mpld3.register_plugin("drag", PPlanePlugin);
    PPlanePlugin.prototype = Object.create(mpld3.Plugin.prototype);
    PPlanePlugin.prototype.constructor = PPlanePlugin;
    PPlanePlugin.prototype.requiredProps = ["id", "idmpoint", "idlinel"];
    PPlanePlugin.prototype.defaultProps = {}
    function PPlanePlugin(fig, props){
        mpld3.Plugin.call(this, fig, props);
        mpld3.insert_css("#" + fig.figid + " path.dragging",
                         {"fill-opacity": "1.0 !important",
                          "stroke-opacity": "1.0 !important"});
    };

    // Call draw function, this function is being looped all the time
    PPlanePlugin.prototype.draw = function(){
        // Get elements into script variables
        var obj = mpld3.get_element(this.props.id);
        var midpoint = mpld3.get_element(this.props.idmpoint);
        var linel = mpld3.get_element(this.props.idlinel);
        
        // Set initial conditions for javascript calculations
        var qleft = obj.offsets[0];
        var qright = obj.offsets[1];
        var qmid = midpoint.offsets[0];
        var zz = 2.0;
        
        var line = d3.svg.line()
    .x(function(d) { return d.x; })
    .y(function(d) { return d.y; })
    .interpolate("basis");
        
        // Main d3 drag function
        var drag = d3.behavior.drag()
            .origin(function(d) { return {x:obj.ax.x(d[0]),
                                          y:obj.ax.y(d[1])}; })                              
            .on("dragstart", dragstarted)
            .on("drag", dragged)
            .on("dragend", dragended);
    
        // Set elements of ql and qr points and call main drag function
        obj.elements()
           .data(obj.offsets)
           .style("cursor", "default")
           .call(drag);      

        // Begin drag function
        function dragstarted(d) {
          d3.event.sourceEvent.stopPropagation();
          d3.select(this).classed("dragging", true);
        }
    
        // The drag function called while dragging is happening (meat of code here)
        function dragged(d,i) {
          // Convert mouse coordinates in drag event (d3.event) to python coordinates d
          d[0] = obj.ax.x.invert(d3.event.x);
          d[1] = obj.ax.y.invert(d3.event.y);             
          // Move ql and qr stored in obj (they have been selected in drag)
          d3.select(this)
            .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
          // If obj corresponds to ql, move all the other left elements 
          if (i==0){
              // In script calculations of middle state
              qleft = [d[0], d[1]];
              var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
              qmid[0] = qleft[0] - alphal*zz;
              qmid[1] = qleft[1] + alphal;
              var xx = obj.ax.x(qmid[0]);
              var yy = obj.ax.y(qmid[1]); 
              // Update middle state point and marker position
              midpoint.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
              linel.data[0] = obj.offsets[0];
              linel.elements().transition().duration(5)
                .attr("d", linel.datafunc(linel.data,linel.pathcodes));
                }
          // if element corresponds to qr
          else {
              // In script calculations of middle state    
              qright = [d[0], d[1]];
              var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
              qmid[0] = qleft[0] - alphal*zz;
              qmid[1] = qleft[1] + alphal;
              var xx = obj.ax.x(qmid[0]);
              var yy = obj.ax.y(qmid[1]);
              // Update middle state point and marker position
              midpoint.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
              linel.data[3] = obj.offsets[1]
              linel.elements().transition().duration(5)
                .attr("d", linel.datafunc(linel.data,linel.pathcodes));  
                }
        }
        // End dragging
        function dragended(d) {
          d3.select(this).classed("dragging", false);
        }
    }
    mpld3.register_plugin("drag", PPlanePlugin); 
    """

    def __init__(self, points, midpoint, linel):
        if isinstance(points, mpl.lines.Line2D):
            suffix = "pts"
        else:
            suffix = None

        self.dict_ = {"type": "drag",
                      "id": utils.get_id(points, suffix),
                      "idmpoint": utils.get_id(midpoint,suffix),
                      "idlinel" : utils.get_id(linel)
                      }


# Create figure
# Create a figure
fig, ax = plt.subplots(1,1, figsize=(4.5, 4.5))
#fig.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=0.95,
#                    hspace=0.3, wspace=0.15)

#Create subfigure ax1 for phaseplane
#ax[0] = fig.add_subplot(2,2,1)

# Calculate ql and qr randomly
qL = np.array([-2.0, 3.0])
qR = np.array([0.0, -2.0])
dq = np.array([qR[0]-qL[0], qR[1]-qL[1]])

# Plot eigenlines using paths as markers
zz = 2.0
rl = np.array([-zz, 1])
rr = np.array([zz,  1])
# Create path following eigenvalues r1 and r2
verts = [
    (-5, 1), 
    (-3, 1), 
    (-1, -3),
    (0, 0),
    (1, 1), 
    (3, 1),
    (5, 1),
    ]
codes = [mpath.Path.MOVETO,
         mpath.Path.CURVE3,
         mpath.Path.CURVE3,
         mpath.Path.CURVE3,
         mpath.Path.CURVE3,
         mpath.Path.CURVE3,
         mpath.Path.CURVE3,
         ]

path = mpath.Path(verts, codes)
#mpath.Path.MOVETO
linel = mpatches.PathPatch(path, facecolor='none', lw=2)
ax.add_patch(linel)


# Plot ql and qr
points = ax.plot([qL[0],qR[0]], [qL[1], qR[1]], 'or', alpha=0.7, markersize=30, markeredgewidth=1)
data = ["q_l", "q_r"] 

#Plot midpoint
alL = (-dq[0] + dq[1]*zz)/(2*zz)
qm = qL + alL*rl 
midpoint = ax.plot(qm[0],qm[1],'ob', alpha=0.5, markersize=20, markeredgewidth=1)

# Set axis 1 properties
ax.set_title("Phase Plane", fontsize=18)
ax.axis([-5,5,-5,5])
ax.set_aspect('equal')
ax.grid(alpha=0.1,color='k', linestyle='--')

# Remove defult mpld3 plugins
plugins.clear(fig)

#Create subfigure ax2 for solution plane
#ax[1] = fig.add_subplot(2,2,3)
# Create solutionl line with six points
xsol = np.array([-5.0,-2.0,-2.0,2.0,2.0,5.0])
qsol1 = 1*xsol
qsol1[0:2] = qL[0]
qsol1[2:4] = qm[0]
qsol1[4:6] = qR[0]


# Call mpld3 custom PPLane plugin to interact with plot
plugins.connect(fig, PPlanePlugin(points[0],midpoint[0],linel))

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el6929837440809841521375"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     // init custom PPLane plugin
#     mpld3.register_plugin("drag", PPlanePlugin);
#     PPlanePlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     PPlanePlugin.prototype.constructor = PPlanePlugin;
#     PPlanePlugin.prototype.requiredProps = ["id", "idmpoint", "idlinel"];
#     PPlanePlugin.prototype.defaultProps = {}
#     function PPlanePlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#         mpld3.insert_css("#" + fig.figid + " path.dragging",
#                          {"fill-opacity": "1.0 !important",
#                           "stroke-opacity": "1.0 !important"});
#     };
#
#     // Call draw function, this function is being looped all the time
#     PPlanePlugin.prototype.draw = function(){
#         // Get elements into script variables
#         var obj = mpld3.get_element(this.props.id);
#         var midpoint = mpld3.get_element(this.props.idmpoint);
#         var linel = mpld3.get_element(this.props.idlinel);
#
#         // Set initial conditions for javascript calculations
#         var qleft = obj.offsets[0];
#         var qright = obj.offsets[1];
#         var qmid = midpoint.offsets[0];
#         var zz = 2.0;
#
#         var line = d3.svg.line()
#     .x(function(d) { return d.x; })
#     .y(function(d) { return d.y; })
#     .interpolate("basis");
#
#         // Main d3 drag function
#         var drag = d3.behavior.drag()
#             .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                           y:obj.ax.y(d[1])}; })
#             .on("dragstart", dragstarted)
#             .on("drag", dragged)
#             .on("dragend", dragended);
#
#         // Set elements of ql and qr points and call main drag function
#         obj.elements()
#            .data(obj.offsets)
#            .style("cursor", "default")
#            .call(drag);
#
#         // Begin drag function
#         function dragstarted(d) {
#           d3.event.sourceEvent.stopPropagation();
#           d3.select(this).classed("dragging", true);
#         }
#
#         // The drag function called while dragging is happening (meat of code here)
#         function dragged(d,i) {
#           // Convert mouse coordinates in drag event (d3.event) to python coordinates d
#           d[0] = obj.ax.x.invert(d3.event.x);
#           d[1] = obj.ax.y.invert(d3.event.y);
#           // Move ql and qr stored in obj (they have been selected in drag)
#           d3.select(this)
#             .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#           // If obj corresponds to ql, move all the other left elements
#           if (i==0){
#               // In script calculations of middle state
#               qleft = [d[0], d[1]];
#               var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
#               qmid[0] = qleft[0] - alphal*zz;
#               qmid[1] = qleft[1] + alphal;
#               var xx = obj.ax.x(qmid[0]);
#               var yy = obj.ax.y(qmid[1]);
#               // Update middle state point and marker position
#               midpoint.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#               linel.data[0] = obj.offsets[0];
#               linel.elements().transition().duration(5)
#                 .attr("d", linel.datafunc(linel.data,linel.pathcodes));
#                 }
#           // if element corresponds to qr
#           else {
#               // In script calculations of middle state
#               qright = [d[0], d[1]];
#               var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
#               qmid[0] = qleft[0] - alphal*zz;
#               qmid[1] = qleft[1] + alphal;
#               var xx = obj.ax.x(qmid[0]);
#               var yy = obj.ax.y(qmid[1]);
#               // Update middle state point and marker position
#               midpoint.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#               linel.data[3] = obj.offsets[1]
#               linel.elements().transition().duration(5)
#                 .attr("d", linel.datafunc(linel.data,linel.pathcodes));
#                 }
#         }
#         // End dragging
#         function dragended(d) {
#           d3.select(this).classed("dragging", false);
#         }
#     }
#     mpld3.register_plugin("drag", PPlanePlugin);
#
#        mpld3.draw_figure("fig_el6929837440809841521375", {"axes": [{"xlim": [-5.0, 5.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "Phase Plane", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 18.0, "position": [0.5, 1.0199123855037833], "rotation": -0.0, "id": "el692997117584"}], "zoomable": true, "images": [], "xdomain": [-5.0, 5.0], "ylim": [-5.0, 5.0], "paths": [{"edgecolor": "#000000", "facecolor": "none", "edgewidth": 2, "pathcodes": ["M", "S", "S", "S"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data03", "id": "el692992718288"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 0.1, "dasharray": "6,6", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 0.1, "dasharray": "6,6", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#000000", "facecolor": "#FF0000", "edgewidth": 1, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 15.0], [3.9780465000000005, 15.0], [7.793698061772802, 13.419505373823625], [10.606601717798213, 10.606601717798213], [13.419505373823625, 7.793698061772802], [15.0, 3.9780465000000005], [15.0, 0.0], [15.0, -3.9780465000000005], [13.419505373823625, -7.793698061772802], [10.606601717798213, -10.606601717798213], [7.793698061772802, -13.419505373823625], [3.9780465000000005, -15.0], [0.0, -15.0], [-3.9780465000000005, -15.0], [-7.793698061772802, -13.419505373823625], [-10.606601717798213, -10.606601717798213], [-13.419505373823625, -7.793698061772802], [-15.0, -3.9780465000000005], [-15.0, 0.0], [-15.0, 3.9780465000000005], [-13.419505373823625, 7.793698061772802], [-10.606601717798213, 10.606601717798213], [-7.793698061772802, 13.419505373823625], [-3.9780465000000005, 15.0], [0.0, 15.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 0.7, "xindex": 0, "data": "data01", "id": "el692976160656pts"}, {"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 1, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 10.0], [2.652031, 10.0], [5.195798707848534, 8.946336915882418], [7.0710678118654755, 7.0710678118654755], [8.946336915882418, 5.195798707848534], [10.0, 2.652031], [10.0, 0.0], [10.0, -2.652031], [8.946336915882418, -5.195798707848534], [7.0710678118654755, -7.0710678118654755], [5.195798707848534, -8.946336915882418], [2.652031, -10.0], [0.0, -10.0], [-2.652031, -10.0], [-5.195798707848534, -8.946336915882418], [-7.0710678118654755, -7.0710678118654755], [-8.946336915882418, -5.195798707848534], [-10.0, -2.652031], [-10.0, 0.0], [-10.0, 2.652031], [-8.946336915882418, 5.195798707848534], [-7.0710678118654755, 7.0710678118654755], [-5.195798707848534, 8.946336915882418], [-2.652031, 10.0], [0.0, 10.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 0.5, "xindex": 0, "da

# %%
# %matplotlib inline
import numpy as np
import jinja2
import json
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.path as mpath
import matplotlib.patches as mpatches


import mpld3
from mpld3 import plugins, utils

class PPlanePlugin(plugins.PluginBase):
    JAVASCRIPT = r"""
    // init custom PPLane plugin
    mpld3.register_plugin("drag", PPlanePlugin);
    PPlanePlugin.prototype = Object.create(mpld3.Plugin.prototype);
    PPlanePlugin.prototype.constructor = PPlanePlugin;
    PPlanePlugin.prototype.requiredProps = ["id", "idmpoint", "idhugol", "idhugor", "idintcl", "idintcr"];
    PPlanePlugin.prototype.defaultProps = {}
    function PPlanePlugin(fig, props){
        mpld3.Plugin.call(this, fig, props);
        mpld3.insert_css("#" + fig.figid + " path.dragging",
                         {"fill-opacity": "1.0 !important",
                          "stroke-opacity": "1.0 !important"});
    };

    // Call draw function, this function is being looped all the time
    PPlanePlugin.prototype.draw = function(){
        // Get elements into script variables
        var obj = mpld3.get_element(this.props.id);
        var midpoint = mpld3.get_element(this.props.idmpoint);
        var hugol = mpld3.get_element(this.props.idhugol);
        var hugor = mpld3.get_element(this.props.idhugor);
        var intcl = mpld3.get_element(this.props.idintcl);
        var intcr = mpld3.get_element(this.props.idintcr);
        
        // Set initial conditions for javascript calculations
        var qleft = obj.offsets[0];
        var qright = obj.offsets[1];
        var qmid = midpoint.offsets[0];
        var iter = 100;
        var zz = 2.0;
        var g = 1.0;
        
        // Main d3 drag function
        var drag = d3.behavior.drag()
            .origin(function(d) { return {x:obj.ax.x(d[0]),
                                          y:obj.ax.y(d[1])}; })                              
            .on("dragstart", dragstarted)
            .on("drag", dragged)
            .on("dragend", dragended);
    
        // Set elements of ql and qr points and call main drag function
        obj.elements()
           .data(obj.offsets)
           .style("cursor", "default")
           .call(drag);      

        // Begin drag function
        function dragstarted(d) {
          d3.event.sourceEvent.stopPropagation();
          d3.select(this).classed("dragging", true);
        }
    
        // The drag function called while dragging is happening (meat of code here)
        function dragged(d,i) {
          // Convert mouse coordinates in drag event (d3.event) to python coordinates d
          d[0] = obj.ax.x.invert(d3.event.x);
          d[1] = obj.ax.y.invert(d3.event.y);             
          // Move ql and qr stored in obj (they have been selected in drag)
          d3.select(this)
            .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
          // If obj corresponds to ql, move all the other left elements 
          if (i==0){
              // In script calculations of middle state
              qleft = [d[0], d[1]];
              var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
              qmid[0] = qleft[0] - alphal*zz;
              qmid[1] = qleft[1] + alphal;
              var xx = obj.ax.x(qmid[0]);
              var yy = obj.ax.y(qmid[1]); 
              // Update middle state point and marker position
              midpoint.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
                
              // Draw Hugoniot loci through left state    
              for (var i=0; i<iter; i++) {
                var hm = hugol.data[i][0];
                var hl = obj.offsets[0][0];
                var hul = obj.offsets[0][1];
                var termHL1 = hm*(hm - hl);
                if (hm == 0) {
                    var termHL2 = 1.0; }
                else {
                    var termHL2 = Math.sqrt(0.5*g*(1.0/hm + 1.0/hl));}
                var termHL3 = termHL1*termHL2;
                hugol.data[i][1] = hul - termHL3 ;  }
              hugol.elements().transition().duration(5)
                  .attr("d", hugol.datafunc(hugol.data));
                  
              // Draw integral curve through left state    
              for (var i=0; i<iter; i++) {
                var hm = intcl.data[i][0];
                var hl = obj.offsets[0][0];
                var hul = obj.offsets[0][1];
                var termIC1 = 2.0*hm*Math.sqrt(g*hl);
                var termIC2 = 2.0*hm*Math.sqrt(g*hm);
                intcl.data[i][1] = hul + termIC1 - termIC2;
              }
              intcl.elements().transition().duration(5)
                  .attr("d", intcl.datafunc(intcl.data));
                  
          }      
          // if element corresponds to qr
          else {
              // In script calculations of middle state    
              qright = [d[0], d[1]];
              var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
              qmid[0] = qleft[0] - alphal*zz;
              qmid[1] = qleft[1] + alphal;
              var xx = obj.ax.x(qmid[0]);
              var yy = obj.ax.y(qmid[1]);
              // Update middle state point and marker position
              midpoint.elements().transition().duration(5)
                .attr("transform", "translate(" + [xx, yy] + ")");
                
              // Draw Hugoniot loci through right state    
              for (var i=0; i<iter; i++) {
                var hm = hugor.data[i][0];
                var hr = obj.offsets[1][0];
                var hur = obj.offsets[1][1];
                var termHL1 = hm*(hm - hr);
                if (hm == 0) {
                    var termHL2 = 1.0; }
                else {
                    var termHL2 = Math.sqrt(0.5*g*(1.0/hm + 1.0/hr));}
                var termHL3 = termHL1*termHL2;
                hugol.data[i][1] = hur + termHL3 ;  }
              hugor.elements().transition().duration(5)
                  .attr("d", hugor.datafunc(hugor.data));
                    
              // Draw integral curve through right state    
              for (var i=0; i<iter; i++) {
                var hm = intcr.data[i][0];
                var hr = obj.offsets[1][0];
                var hur = obj.offsets[1][1];
                var termIC1 = 2.0*hm*Math.sqrt(g*hr);
                var termIC2 = 2.0*hm*Math.sqrt(g*hm);
                intcr.data[i][1] = hur - termIC1 + termIC2;
              }
              intcr.elements().transition().duration(5)
                    .attr("d", intcr.datafunc(intcr.data));
            }
        }
        // End dragging
        function dragended(d) {
          d3.select(this).classed("dragging", false);
        }
    }
    mpld3.register_plugin("drag", PPlanePlugin); 
    """

    def __init__(self, points, midpoint, hugol, hugor, intcl, intcr):
        if isinstance(points, mpl.lines.Line2D):
            suffix = "pts"
        else:
            suffix = None

        self.dict_ = {"type": "drag",
                      "id": utils.get_id(points, suffix),
                      "idmpoint": utils.get_id(midpoint,suffix),
                      "idhugol" : utils.get_id(hugol),
                      "idhugor" : utils.get_id(hugor),
                      "idintcl" : utils.get_id(intcl),
                      "idintcr" : utils.get_id(intcr)
                      }


# Create figure
# Create a figure
fig, ax = plt.subplots(1,1, figsize=(9, 6))
#fig.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=0.95,
#                    hspace=0.3, wspace=0.15)

#Create subfigure ax1 for phaseplane
#ax[0] = fig.add_subplot(2,2,1)

# Calculate ql and qr randomly
qL = np.array([2.0, -3.0])
qR = np.array([4.0, 0.0])
dq = np.array([qR[0]-qL[0], qR[1]-qL[1]])

# Plot eigenlines using paths as markers
zz = 2.0
rl = np.array([-zz, 1])
rr = np.array([zz,  1])

xx = np.linspace(0,10,100)
yy = np.sin(xx)
hugol = ax.plot(xx,yy, '-r', linewidth=2)
hugor = ax.plot(xx,yy, '-r', linewidth=2)
intcl = ax.plot(xx,yy, '-b')
intcr = ax.plot(xx,yy, '-b')

# Plot ql and qr
points = ax.plot([qL[0],qR[0]], [qL[1], qR[1]], 'or', alpha=0.7, markersize=30, markeredgewidth=1)
data = ["q_l", "q_r"] 

#Plot midpoint
alL = (-dq[0] + dq[1]*zz)/(2*zz)
qm = qL + alL*rl 
midpoint = ax.plot(qm[0],qm[1],'ob', alpha=0.5, markersize=20, markeredgewidth=1)

# Set axis 1 properties
ax.set_title("Phase Plane", fontsize=18)
ax.axis([0,10,-15,10])
#ax.set_aspect('equal')
ax.grid(alpha=0.1,color='k', linestyle='--')

# Remove defult mpld3 plugins
plugins.clear(fig)

# Call mpld3 custom PPLane plugin to interact with plot
plugins.connect(fig, PPlanePlugin(points[0],midpoint[0],hugol[0],hugor[0],intcl[0],intcr[0]))

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el22019680991526244311475"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     // init custom PPLane plugin
#     mpld3.register_plugin("drag", PPlanePlugin);
#     PPlanePlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     PPlanePlugin.prototype.constructor = PPlanePlugin;
#     PPlanePlugin.prototype.requiredProps = ["id", "idmpoint", "idhugol", "idhugor", "idintcl", "idintcr"];
#     PPlanePlugin.prototype.defaultProps = {}
#     function PPlanePlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#         mpld3.insert_css("#" + fig.figid + " path.dragging",
#                          {"fill-opacity": "1.0 !important",
#                           "stroke-opacity": "1.0 !important"});
#     };
#
#     // Call draw function, this function is being looped all the time
#     PPlanePlugin.prototype.draw = function(){
#         // Get elements into script variables
#         var obj = mpld3.get_element(this.props.id);
#         var midpoint = mpld3.get_element(this.props.idmpoint);
#         var hugol = mpld3.get_element(this.props.idhugol);
#         var hugor = mpld3.get_element(this.props.idhugor);
#         var intcl = mpld3.get_element(this.props.idintcl);
#         var intcr = mpld3.get_element(this.props.idintcr);
#
#         // Set initial conditions for javascript calculations
#         var qleft = obj.offsets[0];
#         var qright = obj.offsets[1];
#         var qmid = midpoint.offsets[0];
#         var iter = 100;
#         var zz = 2.0;
#         var g = 1.0;
#
#         // Main d3 drag function
#         var drag = d3.behavior.drag()
#             .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                           y:obj.ax.y(d[1])}; })
#             .on("dragstart", dragstarted)
#             .on("drag", dragged)
#             .on("dragend", dragended);
#
#         // Set elements of ql and qr points and call main drag function
#         obj.elements()
#            .data(obj.offsets)
#            .style("cursor", "default")
#            .call(drag);
#
#         // Begin drag function
#         function dragstarted(d) {
#           d3.event.sourceEvent.stopPropagation();
#           d3.select(this).classed("dragging", true);
#         }
#
#         // The drag function called while dragging is happening (meat of code here)
#         function dragged(d,i) {
#           // Convert mouse coordinates in drag event (d3.event) to python coordinates d
#           d[0] = obj.ax.x.invert(d3.event.x);
#           d[1] = obj.ax.y.invert(d3.event.y);
#           // Move ql and qr stored in obj (they have been selected in drag)
#           d3.select(this)
#             .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#           // If obj corresponds to ql, move all the other left elements
#           if (i==0){
#               // In script calculations of middle state
#               qleft = [d[0], d[1]];
#               var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
#               qmid[0] = qleft[0] - alphal*zz;
#               qmid[1] = qleft[1] + alphal;
#               var xx = obj.ax.x(qmid[0]);
#               var yy = obj.ax.y(qmid[1]);
#               // Update middle state point and marker position
#               midpoint.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#
#               // Draw Hugoniot loci through left state
#               for (var i=0; i<iter; i++) {
#                 var hm = hugol.data[i][0];
#                 var hl = obj.offsets[0][0];
#                 var hul = obj.offsets[0][1];
#                 var termHL1 = hm*(hm - hl);
#                 if (hm == 0) {
#                     var termHL2 = 1.0; }
#                 else {
#                     var termHL2 = Math.sqrt(0.5*g*(1.0/hm + 1.0/hl));}
#                 var termHL3 = termHL1*termHL2;
#                 hugol.data[i][1] = hul - termHL3 ;  }
#               hugol.elements().transition().duration(5)
#                   .attr("d", hugol.datafunc(hugol.data));
#
#               // Draw integral curve through left state
#               for (var i=0; i<iter; i++) {
#                 var hm = intcl.data[i][0];
#                 var hl = obj.offsets[0][0];
#                 var hul = obj.offsets[0][1];
#                 var termIC1 = 2.0*hm*Math.sqrt(g*hl);
#                 var termIC2 = 2.0*hm*Math.sqrt(g*hm);
#                 intcl.data[i][1] = hul + termIC1 - termIC2;
#               }
#               intcl.elements().transition().duration(5)
#                   .attr("d", intcl.datafunc(intcl.data));
#
#           }
#           // if element corresponds to qr
#           else {
#               // In script calculations of middle state
#               qright = [d[0], d[1]];
#               var alphal = (-(qright[0] - qleft[0]) + zz*(qright[1] - qleft[1]))/(2*zz);
#               qmid[0] = qleft[0] - alphal*zz;
#               qmid[1] = qleft[1] + alphal;
#               var xx = obj.ax.x(qmid[0]);
#               var yy = obj.ax.y(qmid[1]);
#               // Update middle state point and marker position
#               midpoint.elements().transition().duration(5)
#                 .attr("transform", "translate(" + [xx, yy] + ")");
#
#               // Draw Hugoniot loci through right state
#               for (var i=0; i<iter; i++) {
#                 var hm = hugor.data[i][0];
#                 var hr = obj.offsets[1][0];
#                 var hur = obj.offsets[1][1];
#                 var termHL1 = hm*(hm - hr);
#                 if (hm == 0) {
#                     var termHL2 = 1.0; }
#                 else {
#                     var termHL2 = Math.sqrt(0.5*g*(1.0/hm + 1.0/hr));}
#                 var termHL3 = termHL1*termHL2;
#                 hugol.data[i][1] = hur + termHL3 ;  }
#               hugor.elements().transition().duration(5)
#                   .attr("d", hugor.datafunc(hugor.data));
#
#               // Draw integral curve through right state
#               for (var i=0; i<iter; i++) {
#                 var hm = intcr.data[i][0];
#                 var hr = obj.offsets[1][0];
#                 var hur = obj.offsets[1][1];
#                 var termIC1 = 2.0*hm*Math.sqrt(g*hr);
#                 var termIC2 = 2.0*hm*Math.sqrt(g*hm);
#                 intcr.data[i][1] = hur - termIC1 + termIC2;
#               }
#               intcr.elements().transition().duration(5)
#                     .attr("d", intcr.datafunc(intcr.data));
#             }
#         }
#         // End dragging
#         function dragended(d) {
#           d3.select(this).classed("dragging", false);
#         }
#     }
#     mpld3.register_plugin("drag", PPlanePlugin);
#
#        mpld3.draw_figure("fig_el22019680991526244311475", {"axes": [{"xlim": [0.0, 10.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "Phase Plane", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 18.0, "position": [0.5, 1.0149342891278375], "rotation": -0.0, "id": "el2201968184912"}], "zoomable": true, "images": [], "xdomain": [0.0, 10.0], "ylim": [-15.0, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 0.1, "dasharray": "6,6", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 0.1, "dasharray": "6,6", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines":
